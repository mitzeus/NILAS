# %% [markdown]
# Put the start code here and connect with chat_ui

# %%
from prompts import (
    SYSTEM_PROMPT_STRING,
    SYSTEM_PROMPT_STRING_NEW,
)
from flashcards import swedish75_limited as FLASHCARD_PROMPT_STRING
from models import ask_chat_conv

# TODO "- **Estoy en escuela.** (more natural: “en la escuela,” but **la** is new, so we’ll keep it simple)", prioritize natural answer when user specifically asks for it,
# only then CI can be relatexed

initial_prompt = "I want to practice simple conversation in Swedish."

print(initial_prompt)

ask_chat_conv(
    prompt=initial_prompt,
    system_prompt=SYSTEM_PROMPT_STRING_NEW,
    flashcards=FLASHCARD_PROMPT_STRING,
    keep_history=True,
    target_language=None,
    preferred_language=None,
    level=None,
    log_probs=True,
    top_logprobs=20,
)
# Out:
# I want to practice simple conversation in Swedish.
# hej! jag tala svenska med du.
#
# idag: jag är **glad** eller **ledsen**?
#
# New Vocabulary:
# - (none)
# hej! jag är glad idag också.
#
# idag: du är hungrig eller törstig?
#
# New Vocabulary:
# - (none)
# förlåt—jag förstår lite.
#
# jag: jag är glad eller ledsen.
#
# du: du är glad eller ledsen?
#
# New Vocabulary:
# - (none)
# hej! jag är glad idag.
#
# skola: bra eller dålig?
#
# New Vocabulary:
# - (none)
# skola: bra eller dålig?
#
# New Vocabulary:
# - (none)
# bra! jag är glad.
#
# idag: du läsa bok eller skriva?
#
# New Vocabulary:
# - (none)
# bra! du skriva idag.
#
# idag: du dricka vatten eller kaffe?
#
# New Vocabulary:
# - (none)
# hej! idag: du dricka vatten eller kaffe?
#
# New Vocabulary:
# - (none)
# bra! du dricka **te** (tea). jag dricka vatten.
#
# idag: du är törstig eller hungrig?
#
# New Vocabulary:
# - **te** (tea)
# hej! idag: du är törstig eller hungrig?
#
# New Vocabulary:
# - (none)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 15
#      11 initial_prompt = "I want to practice simple conversation in Swedish."
#      13 print(initial_prompt)
# ---> 15 ask_chat_conv(
#      16     prompt=initial_prompt,
#      17     system_prompt=SYSTEM_PROMPT_STRING_NEW,
#      18     flashcards=FLASHCARD_PROMPT_STRING,
#      19     keep_history=True,
#      20     target_language=None,
#      21     preferred_language=None,
#      22     level=None,
#      23 )
#
# File h:\Applied-AI---HH\Year_3\Bachelor Thesis\Project\chatGPT_conversation_Interface\models.py:66, in ask_chat_conv(prompt, system_prompt, flashcards, keep_history, target_language, preferred_language, level)
#      63 else:
#      64     history = [{"role": "system", "content": system_prompt}]
# ---> 66 new_prompt = input("> ")
#      68 engineered_new_prompt = f"""
#      69     User Question:
#      70     {new_prompt}
#    (...)     77     Preferred Language: {preferred_language}
#      78 """.strip()
#      79 engineered_new_prompt += (
#      80     f"\n Target Language: {target_language}" if target_language != None else ""
#      81 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\ipykernel\kernelbase.py:1320, in Kernel._input_request(self, prompt, ident, parent, password)
#    1317 except KeyboardInterrupt:
#    1318     # re-raise KeyboardInterrupt, to truncate traceback
#    1319     msg = "Interrupted by user"
# -> 1320     raise KeyboardInterrupt(msg) from None
#    1321 except Exception:
#    1322     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
