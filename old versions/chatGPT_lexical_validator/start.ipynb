# %% [markdown]
# Put the start code here and connect with chat_ui

# %%
from prompts import (
    SYSTEM_PROMPT_STRING,
)
from flashcards import swedish75_limited as FLASHCARD_PROMPT_STRING
from models import ask_chat_conv

# TODO "- **Estoy en escuela.** (more natural: “en la escuela,” but **la** is new, so we’ll keep it simple)", prioritize natural answer when user specifically asks for it,
# only then CI can be relatexed

evaluate_sentence = """

Varje dag vaknar jag tidigt, tvättar mitt ansikte, dricker kaffe, äter bröd med ost, går till bussen, sitter och lyssnar på musik, arbetar på ett litet kontor, pratar långsamt med snälla kollegor, skriver enkla mejl, äter lunch med soppa och ris, promenerar efter jobbet till affären, köper mjölk och frukt, går hem, lagar enkel mat, städar lite, ringer min familj, tittar på tv, läser en lätt bok, borstar tänderna och somnar lugnt, och jag känner mig trött men ganska nöjd med mitt vanliga liv, på helgerna sover jag längre och träffar vänner i parken ibland och dricker te tillsammans ofta.
"""

print(evaluate_sentence)

ask_chat_conv(
    prompt=evaluate_sentence,
    system_prompt=SYSTEM_PROMPT_STRING,
    flashcards=FLASHCARD_PROMPT_STRING,
    keep_history=True,
    target_language=None,
    preferred_language=None,
    level=None,
)
# Out:
# Varje dag vaknar jag tidigt, tvättar mitt ansikte, dricker kaffe, äter bröd med ost, går till bussen, sitter och lyssnar på musik, arbetar på ett litet kontor, pratar långsamt med snälla kollegor, skriver enkla mejl, äter lunch med soppa och ris, promenerar efter jobbet till affären, köper mjölk och frukt, går hem, lagar enkel mat, städar lite, ringer min familj, tittar på tv, läser en lätt bok, borstar tänderna och somnar lugnt, och jag känner mig trött men ganska nöjd med mitt vanliga liv, på helgerna sover jag längre och träffar vänner i parken ibland och dricker te tillsammans ofta.
#
# Then give me a reason for counting 'går' as 1 when only "igår" exist as a flashcard
#
# Varje - 0
# dag - 0
# vaknar - 0
# jag - 1
# tidigt - 0
# tvättar - 0
# mitt - 0
# ansikte - 0
# dricker - 1
# kaffe - 1
# äter - 1
# bröd - 0
# med - 1
# ost - 0
# går - 1
# till - 0
# bussen - 0
# sitter - 0
# och - 1
# lyssnar - 0
# på - 1
# musik - 0
# arbetar - 0
# på - 1
# ett - 1
# litet - 1
# ...
